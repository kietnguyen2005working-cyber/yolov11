# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.2/112.6 GB disk)

# %%
# !unzip -o "/content/Dataset Yolo1.zip"
# Out:
# Archive:  /content/Dataset Yolo1.zip
#    creating: Dataset Yolo1/
#   inflating: Dataset Yolo1/dataset.yaml
#    creating: Dataset Yolo1/test/
#    creating: Dataset Yolo1/test/images/
#   inflating: Dataset Yolo1/test/images/image_001.jpg
#   inflating: Dataset Yolo1/test/images/image_004.jpg
#   inflating: Dataset Yolo1/test/images/image_012.jpg
#   inflating: Dataset Yolo1/test/images/image_017.png
#   inflating: Dataset Yolo1/test/images/image_046.jpg
#   inflating: Dataset Yolo1/test/images/image_067.jpg
#   inflating: Dataset Yolo1/test/images/image_068.jpg
#   inflating: Dataset Yolo1/test/images/image_070.jpg
#   inflating: Dataset Yolo1/test/images/image_076.jpg
#   inflating: Dataset Yolo1/test/images/image_092.jpg
#   inflating: Dataset Yolo1/test/images/image_093.jpg
#   inflating: Dataset Yolo1/test/images/image_095.jpeg
#   inflating: Dataset Yolo1/test/images/image_102.jpg
#   inflating: Dataset Yolo1/test/images/image_105.jpeg
# ...

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo train model=yolo11n.pt data="/content/Dataset Yolo1/dataset.yaml" epochs=120 imgsz=640
# Out:
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
